# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('tsukuba/scene1.row3.col1.ppm')
plt.imshow(img)

# %%
oneup = cv2.pyrUp(img)
plt.imshow(oneup)

# %%
onedown = cv2.pyrDown(img)
plt.imshow(onedown)
